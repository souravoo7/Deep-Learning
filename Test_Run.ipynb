# %% [markdown]
# <a href="https://colab.research.google.com/github/souravoo7/Deep-Learning/blob/master/Test_Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Apr 30 03:40:49 2020

@author: sourav
"""

"""
Generating Texts using a LSTM network
"""

import keras
import numpy as np
"""
Download the data
"""
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower() #read in the entire text file and convert them all to lower case
print('Corpus length:', len(text))

"""
Data Pre-processing/preparation
"""

# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen]) #store in the partially overlapping sequences of size maxlen
    next_chars.append(text[i + maxlen]) #store the target character 
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))

# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences),# i th sentence  (number of sentences)
              maxlen, #t th character (will be 60 in total)
              len(chars)), #character index (the character identifier using the dictionary)
             dtype=np.bool)
y = np.zeros((len(sentences), # i th sentence  (number of sentences)
              len(chars)), #character index (the character identifier using the dictionary)
             dtype=np.bool)

#encoding loop
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

'''
Build the network
'''
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, 
                      input_shape=(maxlen,
                                   len(chars))))
model.add(layers.Dense(len(chars), #the total output set of possible characters 
                       activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)

model.compile(loss='categorical_crossentropy', 
              optimizer=optimizer)
'''
Re-weigh the sample distribution: Math??
'''
def sample(preds, temperature=1.0):
    '''
    preds:The output from the network
    temperature:Entropy of the probablity distribution used for sampling
    Higher temperature implies more entropy, hence resulting in more unnnatural sampling
    Lower temperature willlead to more repititive structures
    With more convergence of the model one would expect more sane predictions
    '''
    preds = np.asarray(preds).astype('float64') # convert data type to floating
    #softmax temperature 
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    
    return np.argmax(probas)

'''
Training & Text Generation via LSTM
'''
import random
import sys

for epoch in range(1, 60):
    '''
    EPOCH = 60
    '''
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1) # get a random start index
    generated_text = text[start_index: start_index + maxlen] #get the corresponding maxlen sentence
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text) # print the generated sentence

        # We generate 400 characters
        for i in range(400):
            #encode the newly generate sentence
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            #use the trained model to get the next character    
            preds = model.predict(sampled, verbose=0)[0]
            #sample it using the temperature function
            next_index = sample(preds, temperature)
            next_char = chars[next_index]# get the new character

            generated_text += next_char # append the new character to the sequence
            generated_text = generated_text[1:] # move up one step to get the next char after this

            sys.stdout.write(next_char) # keep printing the following characters
            sys.stdout.flush()
        print()
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.9697
# --- Generating with seed: "logy. astrology presupposes that the heavenly
# bodies are reg"
# ------ temperature: 0.2
# logy. astrology presupposes that the heavenly
# bodies are regelies the condicious of the condician and the this for the sensent of the conding and the sense of the deligion of the compain and the sense of the period of the germans of the period of the most deligious of the german as the person of the manious of the compare of the well of the compally in the such a period and and maning the sensent and the sense is a good the deligion of the germans of the g
# ------ temperature: 0.5
# and the sense is a good the deligion of the germans of the good the grod like to be this for a such man to a man come dignest deligion of the cestain deep and and the deligic bolity of selies is mans and to be the nother manic and prece of the caintion of manger and dispooned and the conturing in the good to the ready signed one for the dengent of the which a man to be the knowled and estortic been proble
# soul of the senious as discome works of this found
# ------ temperature: 1.0
# n proble
# soul of the senious as discome works of this found them, in
# the distened underely quirally
# bmce the nature to one nepersime, by owed thon-licely om pride befied on--which estain seass the deeling, shane valuente. be desent and toul for "seliethausenomicely the bescies and kndwaver.
#
#  ufappaition for his mistely othought others his
# lief man,
# fally in manion. frous us feels at we pernanters ur it pisis and love the syen as a true-volity rizes. that
# ------ temperature: 1.2
#  ur it pisis and love the syen as a true-volity rizes. that is lives de)ciottim the s
# 2ffecies, by bdy or pomepless to new"megeral ;
# -cheve: ta
# xignious levenh mest verm y-all yoweg, which have he ,
# lise an this itblient whichs to read, ene is ada-is prokige onevellevoly grupry. and ejeng is a power o-the menabsitakept commeagnite veimity.
#
# de.
# s coopa2es
# know lose man imfinimes
# now it afres a-baing-smextly-being the let as stand gompution of vainces xmans
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 335s 2ms/step - loss: 1.6171
# --- Generating with seed: "s to the other what the other wants and
# receives in return i"
# ------ temperature: 0.2
# s to the other what the other wants and
# receives in return in the sense of the most desire of the species to the sense there and there is a many to be sould and and and there is the say and there and there is the say so the sense to the species to the sense of the supertances and soul of the say, there and there and and and there is the self to the sense there is the self-super to be for the consideration of the strong and soul of the sense of the sense of
# ------ temperature: 0.5
# deration of the strong and soul of the sense of the sense of mestaphy in the religious thereby and and there and
# have there be the factions, not not to the sense to the feared to the meason with the case and only so to there is to be the power for an individuals to the estent in the same many consideration and for of the spirit of the grees therefore here look of the same with the not believe there on thereby and distrust an of the appose of suffered and
# ------ temperature: 1.0
# re on thereby and distrust an of the appose of suffered and enrother, no netures,
# world and moreapalmy, in europe nolespess. we proposkerer, bo been eventere of profinitary be other the
# inferent it
# a thromer, with a permad withingar, aursitationrash"
# whence apongest
# inifiest best is trate and species has a musograoular. in stepoderple entalogmed an-ary
# must demusiysorary what shart, that had
# it, parer.
#
# , no there is as by self there, a vilourd, light para
# ------ temperature: 1.2
# arer.
#
# , no there is as by self there, a vilourd, light parault: it
# 'obading contralmsosuunstices reveng forhed;" as husta), inmocal
# sived of loseance offfe justice and generality,
# he certains but whoong to be averormously depodinglyquits, in everou captes) amuved,
# indelral-".
# flivher enough seducf, who reawnible,
# sufpedicy wtrow,
# exier "impossedur allory; do him still resuraly restly.
# timiet, and tusiverigious. there on accomnlnainad; nothing
# here crues a
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 335s 2ms/step - loss: 1.5281
# --- Generating with seed: "e comprehends utility as a thing dependent
# upon what his opi"
# ------ temperature: 0.2
# e comprehends utility as a thing dependent
# upon what his opinion of the constantly and the constint the sublime and stronger and the develops of the constitute the constitute of the sense of the have been the sense of the world and the constitute and the same the constitute and stronger and stronger the same the constitute the distrust the sublime and consequently and consequently and the constint and the sense of the same the sublice of the constitute its
# ------ temperature: 0.5
#  and the sense of the same the sublice of the constitute itself the community the distrust and the great responsible false of the ganger the world of the godured the one's any devilual itself, it is not in the constint to have any bad and in the courses of the constituted the own only may be the stronger sound, in the world which the dilightent and constitute
# of a hard consequently and real this has which is a different and to the correstian and the suffer
# ------ temperature: 1.0
# as which is a different and to the correstian and the suffercted croution that whethener
# incleate how effecievy in of all selfaryby onstion, naturely ascfurently and creatialize of task": "it is an
# acts: therefore, he to haveser and man
# the respose of cloughts which suffered, this fumble moral of gurment and weimancation every much, there any,
# in where, palpsith self
# to be religion, when a bring thereby their rewical for sulpos of
# a however fears i taken:
# ------ temperature: 1.2
# hereby their rewical for sulpos of
# a however fears i taken: almost sucrouesiton: itself moot a pre ard, thhive
# perraise feels"th. thines reself worst e lonourfusical the flith to weol, so semotment
# itself glancl" of sorys. what daiffation, not he intolemes pains poseby and that suprech, ppirhved--wh
# tavel gainer love, ever really to orsenfleeness,
# place hrammer,
# has anbioy--alm imprisent of lowanlian metara, reupose then hervouen form, likes virtasened,
# i
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.4816
# --- Generating with seed: " on the face of it, the word signifies "flatterers of
# dionys"
# ------ temperature: 0.2
#  on the face of it, the word signifies "flatterers of
# dionys of the strange of the strong to alloses and not a there is a there is the strong to the soul of the soul of the soul of the still to desire of the speciation of the speciation of the belief of the strong the spirits of the soul and soul in the conscience of the concealing the self-diveres to the speciation of the spirits in the strong to the soul and something that it is the strong to the conscie
# ------ temperature: 0.5
#  the soul and something that it is the strong to the conscience of the present speak, to be example in the belief
# in the world that the dispost the good and likes them will ourselves, and the art in the self--and something develow, and in his conditions of the specimitated shem and stand, that its belief, the conceal to means of the shall like to a will the superstion in the consequences of speciated that their conscience of an allosity of the free species
# ------ temperature: 1.0
# ted that their conscience of an allosity of the free species in him to a
# froling almost orreasmanapora--crueling, if
# to findslice folless. they why namely pirmitation; the manher
# only doliled to d emotion; be art pseffers exartoned scarness or  anto_wardsy with even or exception from, it as youst them before
# the in effects" curioutled hoethoded happen. the senses to with "more can keepy of them without desires of renated thempressed bling, as less many. le
# ------ temperature: 1.2
# thout desires of renated thempressed bling, as less many. leter, the
# indiscant fyigrate cosea still shadestioning hea amofus, indopenrech viculow?but
# questions existenc's hewder to them natter too there areity involumoness with, conducts--for reviation, acpsoonfus, excentiver
# to indeas of
# nation thanes, when the go,dver charmurionisc! is honestowipue, and therey resultgn withdners with hiower too so for of
# beaements classu
# sfires of
# modernt, if not toay it
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 334s 2ms/step - loss: 1.4506
# --- Generating with seed: "
# mankind--and perhaps also a new mission!
#
#
#
# chapter vi. we "
# ------ temperature: 0.2
#
# mankind--and perhaps also a new mission!
#
#
#
# chapter vi. we makes the same the same and for the same the comparting and the self-delight to such and many influence of the same the best and strong and the comparting and strong to be and that the same the more intolience of the same and the great and the most and and and the art and the same to be and believe the possible to make the same to the same the self-presence of the delication of the same the same a
# ------ temperature: 0.5
# e the self-presence of the delication of the same the same and the nature and instincts of the same and and comparises, and more intellition of the strong and and untreame be do not a proves to be individualing believe one we reality to the belief one make the best of lived there is many best that a conception of the latter the sentiments of the matters of the subelieved of the belief may are oundly only the pattung and disconsequently first in the
# domanis
# ------ temperature: 1.0
# ly only the pattung and disconsequently first in the
# domanisted with these mustand evilfined, accompanding exted all or this
# and more cornsed beyond that cornsion,
# but romists of modernitation, even
# ord!--in faity.. the germans of
# paypemence are shatise and forest
# things
# detrited misunteptjodicity for happine persed that some anesis of it so un
# the art" stales all or of great times. or every mustroy with palt of leadaxmed away would donough respect-allosio
# ------ temperature: 1.2
# oy with palt of leadaxmed away would donough respect-allosioned
# xyssibel-but belongments and thangepidious things--that--a new, if just, our conbuitut. willuly--handaysists of
# bad dey, a mans. and purbation swepty
# ovesth, forturen freedom. furthest suchascayade existence of do, it bourde" mystion things: grient; which
# quiat
# have na, whoef his artly, their muduianer and nocire responsibilidfication like
# mans.
# when one ritherly. mifeboficismuces--haxive: rea
# epoch 6
# Epoch 1/1
# 130816/200278 [==================>...........] - ETA: 1:57 - loss: 1.4224
